# %%
import psycopg2
import pandas as pd
import os
import re
import sqlalchemy as sa
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 500)

# %%
conn_str = 'postgresql+psycopg2://tinaliu:@127.0.0.1:5432/tennis_atp'
conn_eng = sa.create_engine(conn_str, echo=False)
conn_sa = conn_eng.connect()

# %%
conn.close()

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=tennis_atp user=tinaliu password=")
cur = conn.cursor()
# conn.close()

# %% [markdown]
# Raw Data Dump

# %%
ptn_csv = re.compile('atp_matches_.*.csv')
file_dir = os.getcwd() + '/tennis_atp'
data_source_list = list(filter(ptn_csv.search, os.listdir(file_dir)))

# %%
schema = ['tourney_id',
 'tourney_name',
 'surface',
 'draw_size',
 'tourney_level',
 'tourney_date',
 'match_num',
 'winner_id',
 'winner_seed',
 'winner_entry',
 'winner_name',
 'winner_hand',
 'winner_ht',
 'winner_ioc',
 'winner_age',
 'loser_id',
 'loser_seed',
 'loser_entry',
 'loser_name',
 'loser_hand',
 'loser_ht',
 'loser_ioc',
 'loser_age',
 'score',
 'best_of',
 'round',
 'minutes',
 'w_ace',
 'w_df',
 'w_svpt',
 'w_1stIn',
 'w_1stWon',
 'w_2ndWon',
 'w_SvGms',
 'w_bpSaved',
 'w_bpFaced',
 'l_ace',
 'l_df',
 'l_svpt',
 'l_1stIn',
 'l_1stWon',
 'l_2ndWon',
 'l_SvGms',
 'l_bpSaved',
 'l_bpFaced',
 'winner_rank',
 'winner_rank_points',
 'loser_rank',
 'loser_rank_points']

# %%
df_all = []
for f in data_source_list:
    df = pd.read_csv(os.path.join(file_dir,f))[schema]
    df_all.append(df)

# %%
source = pd.concat(df_all)

# %%
source.to_sql('atp_matches_log', conn_sa, index=False)

# %% [markdown]
# Data ETL from matches

# %%
list(matches.columns)
# Out:
# ['tourney_id',
#  'tourney_name',
#  'surface',
#  'draw_size',
#  'tourney_level',
#  'tourney_date',
#  'match_num',
#  'winner_id',
#  'winner_seed',
#  'winner_entry',
#  'winner_name',
#  'winner_hand',
#  'winner_ht',
#  'winner_ioc',
#  'winner_age',
#  'loser_id',
#  'loser_seed',
#  'loser_entry',
#  'loser_name',
#  'loser_hand',
#  'loser_ht',
#  'loser_ioc',
#  'loser_age',
#  'score',
#  'best_of',
#  'round',
#  'minutes',
#  'w_ace',
#  'w_df',
#  'w_svpt',
#  'w_1stIn',
#  'w_1stWon',
#  'w_2ndWon',
#  'w_SvGms',
#  'w_bpSaved',
#  'w_bpFaced',
#  'l_ace',
#  'l_df',
#  'l_svpt',
#  'l_1stIn',
#  'l_1stWon',
#  'l_2ndWon',
#  'l_SvGms',
#  'l_bpSaved',
#  'l_bpFaced',
#  'winner_rank',
#  'winner_rank_points',
#  'loser_rank',
#  'loser_rank_points']

# %%
qual_chall = pd.read_csv('tennis_atp/atp_matches_qual_chall_2019.csv')
future = pd.read_csv('tennis_atp/atp_matches_futures_2019.csv')

# %%
qual_chall['best_of'].unique()
# Out:
# array([3])

# %% [markdown]
# player

# %%
def get_player_info(matches: pd.DataFrame):
    winner_col = ['tourney_date', 'winner_id', 'winner_name', 'winner_ioc', 'winner_hand', 'winner_age']
    loser_col = ['tourney_date','loser_id', 'loser_name', 'loser_ioc', 'loser_hand', 'loser_age']
    to_col = ['tourney_date','id', 'name', 'country', 'hand', 'age']
    schema = ['id', 'first_name', 'last_name', 'hand', 'birth_year', 'country']
    
    winner = matches[winner_col]
    winner.columns = to_col
    loser = matches[loser_col]
    loser.columns = to_col
    
    player = pd.concat([winner, loser]).drop_duplicates()
    player['first_name'] = player['name'].apply(lambda x: x.split(" ")[0])
    player['last_name'] = player['name'].apply(lambda x: x.split(" ")[len(x.split(" "))-1])
    player['birth_year'] = (pd.to_datetime(player['tourney_date'], format='%Y%m%d') 
                            - pd.to_timedelta(player['age'], unit='y')).dt.year
    return player[schema]

# %% [markdown]
# ranking

# %%
def get_ranking_info(matches: pd.DataFrame):
    winner_col = ['tourney_date', 'winner_id', 'winner_seeds', 'winner_rank', 'winner_rank_points']
    loser_col = ['tourney_date', 'loser_id', 'loser_seeds', 'loser_rank', 'loser_rank_points']
    to_col = ['ranking_date', 'player_id', 'seed', 'rank', 'points']
    schema = ['ranking_date', 'rank', 'player_id', 'seed', 'points']
    
    winner = matches[winner_col]
    winner.columns = to_col
    loser = matches[loser_col]
    loser.columns = to_col
    
    ranking = pd.concat([winner, loser]).drop_duplicates()
    ranking['ranking_date'] = pd.to_datetime(ranking['ranking_date'], format='%Y%m%d').dt.date.astype(str)
    
    return ranking[schema]

# %% [markdown]
# tourney

# %%
def get_tourney_info(matches: pd.DataFrame):
    from_col = ['tourney_id', 'tourney_name', 'tourney_date', 'surface', 'tourney_level']
    schema = ['id', 'name', 'date', 'surface', 'level']
    
    tourney = matches[from_col].drop_duplicates()
    tourney.columns = schema
    tourney['year'] = pd.to_datetime(tourney['date'], format='%Y%m%d').dt.year
    tourney['date'] = pd.to_datetime(tourney['date'], format='%Y%m%d').dt.date.astype(str)
    
    return tourney[schema]

# %% [markdown]
# match

# %%
def get_matches_info(matches):
    from_col = ['tourney_id', 'match_num', 'round', 'minutes', 'winner_id', 'loser_id', 'score']
    schema = ['tourney_id', 'match_id', 'round', 'minutes', 'winner_id', 'loser_id', 'score']
    
    matches = matches[from_col]
    matches.columns = schema
    
    set_score = matches['score'].str.split(" ", n = 4, expand = True)
    set_num = set_score.shape[1]
    set_cols = [f'score_set{i}' for i in range(1,set_num+1)]
    
    matches[set_cols] = set_score
    
    return matches.drop(['score'], axis=1)

# %%
def insert_update_pd(df, cur, table_name):
    schema = ','.join(df.columns)
    for i, row in df.iterrows():
        values = tuple(row.values)
        update_str = ', '.join([f"{k} = '{v}'" for k,v in row.to_dict().items()])
        insert_update_query = f""" 
        INSERT INTO {table_name} ({schema})
        VALUES ({values})
        ON CONFLICT 
        DO UPDATE 
        SET {update_str}
        """
        print(insert_update_query)
#         cur.execute(insert_update_query)
    
    print(f'[{table_name}] processed')

# %%
player = get_player_info(matches)

# %%
ranking = get_ranking_info(matches)

# %%
tourney = get_tourney_info(qual_chall)

# %%
match = get_matches_info(qual_chall)

# %%
qual_chall = pd.read_csv('tennis_atp/atp_matches_qual_chall_2019.csv')

# %% [markdown]
# ? Highest ranking for each tourney for specific players
#
# ? tourney champions

# %% [markdown]
# data ETL

# %%
matches['tourney_id'].unique()
# Out:
# array(['2019-M020', '2019-0451', '2019-0891', '2019-0301', '2019-M001',
#        '2019-580', '2019-M-DC-2019-QLS-M-AUS-BIH-01',
#        '2019-M-DC-2019-QLS-M-AUT-CHI-01',
#        '2019-M-DC-2019-QLS-M-BEL-BRA-01',
#        '2019-M-DC-2019-QLS-M-CAN-SVK-01',
#        '2019-M-DC-2019-QLS-M-CZE-NED-01',
#        '2019-M-DC-2019-QLS-M-GER-HUN-01',
#        '2019-M-DC-2019-QLS-M-ITA-IND-01',
#        '2019-M-DC-2019-QLS-M-JPN-CHN-01',
#        '2019-M-DC-2019-QLS-M-KAZ-POR-01',
#        '2019-M-DC-2019-QLS-M-SRB-UZB-01',
#        '2019-M-DC-2019-QLS-M-SUI-RUS-01',
#        '2019-M-DC-2019-QLS-M-SWE-COL-01', '2019-9158', '2019-0375',
#        '2019-7434', '2019-0506', '2019-0424', '2019-0407', '2019-0499',
#        '2019-0496', '2019-6932', '2019-M004', '2019-0495', '2019-0533'],
#       dtype=object)

# %%
future.loc[future['tourney_id'] == '2019-M-ITF-CHN-01A-2019'].sort_values('match_num', ascending=False)
# Out:
#                  tourney_id tourney_name surface  draw_size tourney_level  \
# 30  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 29  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 28  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 27  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 26  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 25  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 24  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 23  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 22  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 21  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 20  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 19  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 18  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 17  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 16  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 15  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 14  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 13  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 12  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 11  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 10  2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 9   2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 8   2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 7   2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 6   2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 5   2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 4   2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 3   2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 2   2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 1   2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
# 0   2019-M-ITF-CHN-01A-2019   M15 Anning    Clay        NaN             S
#
#     tourney_date  match_num  winner_id  winner_seed winner_entry  \
# 30      20181231         31     208322          NaN          NaN
# 29      20181231         30     132573          NaN          NaN
# 28      20181231         29     208322          NaN          NaN
# 27      20181231         28     134113          NaN          NaN
# 26      20181231         27     132573          NaN          NaN
# 25      20181231         26     106074          NaN          NaN
# 24      20181231         25     208322          NaN          NaN
# 23      20181231         24     134113          NaN          NaN
# 22      20181231         23     133684          NaN          NaN
# 21      20181231         22     200666          3.0          NaN
# 20      20181231         21     132573          NaN          NaN
# 19      20181231         20     106074          NaN          NaN
# 18      20181231         19     200307          NaN          NaN
# 17      20181231         18     208322          NaN          NaN
# 16      20181231         17     104251          NaN          NaN
# 15      20181231         16     133068          NaN          NaN
# 14      20181231         15     134113          NaN          NaN
# 13      20181231         14     133684          NaN          NaN
# 12      20181231         13     104822          NaN          NaN
# 11      20181231         12     200666          3.0          NaN
# 10      20181231         11     144955          NaN            Q
# 9       20181231         10     133687          NaN            Q
# 8       20181231          9     132573          NaN          NaN
# 7       20181231          8     144925          NaN          NaN
# 6       20181231          7     106074          NaN          NaN
# 5       20181231          6     200307          NaN          NaN
# 4       20181231          5     105507          NaN          NaN
# 3       20181231          4     144744          8.0          NaN
# 2       20181231          3     208322          NaN          NaN
# 1       20181231          2     207383          NaN          NaN
# 0       20181231          1     104251          NaN          NaN
#
#                  winner_name winner_hand  winner_ht winner_ioc  winner_age  \
# 30          Eric Vanshelboim           U        NaN        UKR       17.46
# 29          Luca Castelnuovo           U        NaN        SUI       21.92
# 28          Eric Vanshelboim           U        NaN        UKR       17.46
# 27            Cing Yang Meng           U        NaN        TPE       20.45
# 26          Luca Castelnuovo           U        NaN        SUI       21.92
# 25             Jung Woong Na           U        NaN        KOR       26.17
# 24          Eric Vanshelboim           U        NaN        UKR       17.46
# 23            Cing Yang Meng           U        NaN        TPE       20.45
# 22                    Hao Wu           U        NaN        CHN       21.88
# 21                   Jie Cui           U        NaN        CHN       20.93
# 20          Luca Castelnuovo           U        NaN        SUI       21.92
# 19             Jung Woong Na           U        NaN        KOR       26.17
# 18                    Tao Mu           U        NaN        CHN       18.67
# 17          Eric Vanshelboim           U        NaN        UKR       17.46
# 16                   Ti Chen           R      183.0        TPE       35.24
# 15               Haitong Xia           U        NaN        CHN       22.98
# 14            Cing Yang Meng           U        NaN        TPE       20.45
# 13                    Hao Wu           U        NaN        CHN       21.88
# 12  N Vijay Sundar Prashanth           R        NaN        IND       32.18
# 11                   Jie Cui           U        NaN        CHN       20.93
# 10             Yuichiro Inui           R        NaN        JPN       23.75
# 9                   Zhe Zhou           U        NaN        CHN       22.20
# 8           Luca Castelnuovo           U        NaN        SUI       21.92
# 7          Nitin Kumar Sinha           U        NaN        IND       19.86
# 6              Jung Woong Na           U        NaN        KOR       26.17
# 5                     Tao Mu           U        NaN        CHN       18.67
# 4             Cheong Eui Kim           R        NaN        KOR       28.77
# 3           Kazuki Nishiwaki           R        NaN        JPN       24.17
# 2           Eric Vanshelboim           U        NaN        UKR       17.46
# 1            Taisei Ichikawa           U        NaN        JPN       18.03
# 0                    Ti Chen           R      183.0        TPE       35.24
#
#     loser_id  loser_seed loser_entry                loser_name loser_hand  \
# 30    132573         NaN         NaN          Luca Castelnuovo          U
# 29    134113         NaN         NaN            Cing Yang Meng          U
# 28    106074         NaN         NaN             Jung Woong Na          U
# 27    133684         NaN         NaN                    Hao Wu          U
# 26    200666         3.0         NaN                   Jie Cui          U
# 25    200307         NaN         NaN                    Tao Mu          U
# 24    104251         NaN         NaN                   Ti Chen          R
# 23    133068         NaN         NaN               Haitong Xia          U
# 22    104822         NaN         NaN  N Vijay Sundar Prashanth          R
# 21    144955         NaN           Q             Yuichiro Inui          R
# 20    133687         NaN           Q                  Zhe Zhou          U
# 19    144925         NaN         NaN         Nitin Kumar Sinha          U
# 18    105507         NaN         NaN            Cheong Eui Kim          R
# 17    144744         8.0         NaN          Kazuki Nishiwaki          R
# 16    207383         NaN         NaN           Taisei Ichikawa          U
# 15    126335         2.0         NaN               Sora Fukuda          L
# 14    208451         NaN         NaN               Naifu Zhang          U
# 13    111800         NaN         NaN            Weiqiang Zheng          U
# 12    126556         NaN         NaN                Wei De Lin          U
# 11    207594         NaN         NaN                Liran Chen          U
# 10    144831         NaN         NaN             Shi Hong Zeng          U
# 9     127189         NaN         NaN                Li Wie Tan          U
# 8     124074         NaN           Q            Kazuma Kawachi          R
# 7     122620         7.0         NaN         Soichiro Moritani          R
# 6     106036         NaN         NaN               Ruikai Wang          U
# 5     110773         NaN         NaN             Issei Okamura          U
# 4     202052         NaN         NaN                    Ray Ho          L
# 3     126900         NaN         NaN              Ruixuan Wang          U
# 2     121433         NaN         NaN                Ya Hui Nie          U
# 1     202168         NaN         NaN                Ye Cong Mo          U
# 0     200562         NaN         NaN      Anirudh Chandrasekar          L
#
#     loser_ht loser_ioc  loser_age           score  best_of round  minutes  \
# 30       NaN       SUI      21.92         6-3 6-2        3     F      NaN
# 29       NaN       TPE      20.45         6-2 6-3        3    SF      NaN
# 28       NaN       KOR      26.17  6-7(1) 7-5 6-4        3    SF      NaN
# 27       NaN       CHN      21.88         6-4 6-1        3    QF      NaN
# 26       NaN       CHN      20.93      7-6(7) 7-5        3    QF      NaN
# 25       NaN       CHN      18.67         7-5 7-5        3    QF      NaN
# 24     183.0       TPE      35.24         6-0 6-2        3    QF      NaN
# 23       NaN       CHN      22.98         6-0 6-1        3   R16      NaN
# 22       NaN       IND      32.18         7-5 6-2        3   R16      NaN
# 21       NaN       JPN      23.75         6-2 6-2        3   R16      NaN
# 20       NaN       CHN      22.20         6-4 6-3        3   R16      NaN
# 19       NaN       IND      19.86         6-4 6-4        3   R16      NaN
# 18       NaN       KOR      28.77         6-3 6-4        3   R16      NaN
# 17       NaN       JPN      24.17     4-6 6-1 6-4        3   R16      NaN
# 16       NaN       JPN      18.03     6-2 3-6 6-3        3   R16      NaN
# 15       NaN       JPN      21.24     6-4 3-6 6-3        3   R32      NaN
# 14       NaN       UNK      20.16         6-0 6-0        3   R32      NaN
# 13       NaN       CHN      22.52     4-6 7-5 6-3        3   R32      NaN
# 12       NaN       TPE      22.90         6-2 6-1        3   R32      NaN
# 11       NaN       CHN      21.35      7-6(1) 6-2        3   R32      NaN
# 10       NaN       CHN      21.45  6-3 6-7(6) 6-1        3   R32      NaN
# 9        NaN       TPE      23.33         6-4 7-5        3   R32      NaN
# 8        NaN       JPN      24.22         6-4 6-3        3   R32      NaN
# 7        NaN       JPN      24.39  6-1 6-7(3) 6-3        3   R32      NaN
# 6        NaN       CHN      26.40         6-2 6-2        3   R32      NaN
# 5        NaN       JPN      26.60     3-6 6-2 7-5        3   R32      NaN
# 4        NaN       TPE      18.88     6-3 3-6 6-3        3   R32      NaN
# 3        NaN       CHN      22.76     1-6 6-2 6-4        3   R32      NaN
# 2        NaN       CHN      26.68         6-0 6-1        3   R32      NaN
# 1        NaN       CHN      18.51         6-2 6-4        3   R32      NaN
# 0        NaN       IND      20.47     4-6 6-1 6-4        3   R32      NaN
#
#     w_ace  w_df  w_svpt  w_1stIn  w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  \
# 30    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 29    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 28    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 27    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 26    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 25    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 24    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 23    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 22    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 21    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 20    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 19    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 18    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 17    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 16    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 15    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 14    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 13    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 12    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 11    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 10    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 9     NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 8     NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 7     NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 6     NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 5     NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 4     NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 3     NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 2     NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 1     NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 0     NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
#
#     w_bpFaced  l_ace  l_df  l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  \
# 30        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 29        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 28        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 27        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 26        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 25        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 24        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 23        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 22        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 21        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 20        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 19        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 18        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 17        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 16        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 15        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 14        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 13        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 12        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 11        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 10        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 9         NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 8         NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 7         NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 6         NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 5         NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 4         NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 3         NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 2         NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 1         NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 0         NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
#
#     l_bpSaved  l_bpFaced  winner_rank  winner_rank_points  loser_rank  \
# 30        NaN        NaN          NaN                 NaN         NaN
# 29        NaN        NaN          NaN                 NaN         NaN
# 28        NaN        NaN          NaN                 NaN         NaN
# 27        NaN        NaN          NaN                 NaN         NaN
# 26        NaN        NaN          NaN                 NaN       657.0
# 25        NaN        NaN          NaN                 NaN         NaN
# 24        NaN        NaN          NaN                 NaN       502.0
# 23        NaN        NaN          NaN                 NaN         NaN
# 22        NaN        NaN          NaN                 NaN         NaN
# 21        NaN        NaN        657.0                 1.0         NaN
# 20        NaN        NaN          NaN                 NaN         NaN
# 19        NaN        NaN          NaN                 NaN         NaN
# 18        NaN        NaN          NaN                 NaN         NaN
# 17        NaN        NaN          NaN                 NaN         NaN
# 16        NaN        NaN        502.0                11.0         NaN
# 15        NaN        NaN          NaN                 NaN       653.0
# 14        NaN        NaN          NaN                 NaN         NaN
# 13        NaN        NaN          NaN                 NaN         NaN
# 12        NaN        NaN          NaN                 NaN         NaN
# 11        NaN        NaN        657.0                 1.0         NaN
# 10        NaN        NaN          NaN                 NaN         NaN
# 9         NaN        NaN          NaN                 NaN         NaN
# 8         NaN        NaN          NaN                 NaN         NaN
# 7         NaN        NaN          NaN                 NaN         NaN
# 6         NaN        NaN          NaN                 NaN         NaN
# 5         NaN        NaN          NaN                 NaN         NaN
# 4         NaN        NaN          NaN                 NaN         NaN
# 3         NaN        NaN          NaN                 NaN         NaN
# 2         NaN        NaN          NaN                 NaN         NaN
# 1         NaN        NaN          NaN                 NaN         NaN
# 0         NaN        NaN        502.0                11.0         NaN
#
#     loser_rank_points
# 30                NaN
# 29                NaN
# 28                NaN
# 27                NaN
# 26                1.0
# 25                NaN
# 24               11.0
# 23                NaN
# 22                NaN
# 21                NaN
# 20                NaN
# 19                NaN
# 18                NaN
# 17                NaN
# 16                NaN
# 15                1.0
# 14                NaN
# 13                NaN
# 12                NaN
# 11                NaN
# 10                NaN
# 9                 NaN
# 8                 NaN
# 7                 NaN
# 6                 NaN
# 5                 NaN
# 4                 NaN
# 3                 NaN
# 2                 NaN
# 1                 NaN
# 0                 NaN

# %%
matches[['tourney_id', 'tourney_name']].drop_duplicates()
# Out:
#                           tourney_id                  tourney_name
# 0                          2019-M020                      Brisbane
# 27                         2019-0451                          Doha
# 58                         2019-0891                          Pune
# 85                         2019-0301                      Auckland
# 112                        2019-M001                        Sydney
# 139                         2019-580               Australian Open
# 266  2019-M-DC-2019-QLS-M-AUS-BIH-01  Davis Cup QLS R1: AUS vs BIH
# 269  2019-M-DC-2019-QLS-M-AUT-CHI-01  Davis Cup QLS R1: AUT vs CHI
# 273  2019-M-DC-2019-QLS-M-BEL-BRA-01  Davis Cup QLS R1: BEL vs BRA
# 276  2019-M-DC-2019-QLS-M-CAN-SVK-01  Davis Cup QLS R1: CAN vs SVK
# 280  2019-M-DC-2019-QLS-M-CZE-NED-01  Davis Cup QLS R1: CZE vs NED
# 283  2019-M-DC-2019-QLS-M-GER-HUN-01  Davis Cup QLS R1: GER vs HUN
# 287  2019-M-DC-2019-QLS-M-ITA-IND-01  Davis Cup QLS R1: ITA vs IND
# 290  2019-M-DC-2019-QLS-M-JPN-CHN-01  Davis Cup QLS R1: JPN vs CHN
# 294  2019-M-DC-2019-QLS-M-KAZ-POR-01  Davis Cup QLS R1: KAZ vs POR
# 297  2019-M-DC-2019-QLS-M-SRB-UZB-01  Davis Cup QLS R1: SRB vs UZB
# 301  2019-M-DC-2019-QLS-M-SUI-RUS-01  Davis Cup QLS R1: SUI vs RUS
# 304  2019-M-DC-2019-QLS-M-SWE-COL-01  Davis Cup QLS R1: SWE vs COL
# 307                        2019-9158                       Cordoba
# 334                        2019-0375                   Montpellier
# 361                        2019-7434                         Sofia
# 388                        2019-0506                  Buenos Aires
# 415                        2019-0424                      New York
# 442                        2019-0407                     Rotterdam
# 473                        2019-0499                  Delray Beach
# 504                        2019-0496                     Marseille
# 531                        2019-6932                Rio De Janeiro
# 562                        2019-M004                      Acapulco
# 593                        2019-0495                         Dubai
# 624                        2019-0533                     Sao Paulo

# %%
matches.loc[(matches['winner_name'] == 'Novak Djokovic'), 
            ['tourney_name','match_num','round','winner_rank','winner_rank_points','winner_name']]
# Out:
#         tourney_name  match_num round  winner_rank  winner_rank_points  \
# 42              Doha        285   R32          1.0              9045.0
# 50              Doha        293   R16          1.0              9045.0
# 54              Doha        297    QF          1.0              9045.0
# 139  Australian Open        100  R128          1.0              9135.0
# 203  Australian Open        164   R64          1.0              9135.0
# 235  Australian Open        196   R32          1.0              9135.0
# 251  Australian Open        212   R16          1.0              9135.0
# 259  Australian Open        220    QF          1.0              9135.0
# 263  Australian Open        224    SF          1.0              9135.0
# 265  Australian Open        226     F          1.0              9135.0
#
#         winner_name
# 42   Novak Djokovic
# 50   Novak Djokovic
# 54   Novak Djokovic
# 139  Novak Djokovic
# 203  Novak Djokovic
# 235  Novak Djokovic
# 251  Novak Djokovic
# 259  Novak Djokovic
# 263  Novak Djokovic
# 265  Novak Djokovic

# %%
qual_chall.loc[qual_chall['tourney_id'] == '2019-6932',['tourney_date','match_num', 'round']].drop_duplicates()
# Out:
#       tourney_date  match_num round
# 1343      20190218        243    Q1
# 1344      20190218        244    Q1
# 1345      20190218        245    Q1
# 1346      20190218        246    Q1
# 1347      20190218        247    Q1
# 1348      20190218        248    Q1
# 1349      20190218        249    Q1
# 1350      20190218        250    Q1
# 1351      20190218        251    Q2
# 1352      20190218        252    Q2
# 1353      20190218        253    Q2
# 1354      20190218        254    Q2
